# %%
import pandas as pd
import nltk
import gensim
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from gensim.parsing.preprocessing import STOPWORDS
import numpy as np
import pickle
nltk.download('stopwords')
nltk.download('wordnet')
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import re
import string

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from gensim import corpora,models

# %%
from gensim.models import Word2Vec,FastText
from gensim.test.utils import get_tmpfile
from glove import Glove, Corpus

# %%
from scipy.spatial import distance
import pandas as pd
import nltk
import gensim
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from gensim.parsing.preprocessing import STOPWORDS
import numpy as np
from gensim import corpora,models
import time
import pickle
nltk.download('stopwords')
nltk.download('wordnet')
from sklearn.metrics.pairwise import cosine_similarity
import warnings
from gensim.models import Word2Vec,FastText
from sklearn.decomposition import PCA
from scipy.spatial import distance
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import pandas as pd
import nltk
import gensim
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from gensim.parsing.preprocessing import STOPWORDS
import numpy as np
import pickle
nltk.download('stopwords')
nltk.download('wordnet')

# %%
firefox_data=pd.read_csv('firefox_total_data_preprocessed.csv')
firefox_data
# Out:
#         Bug ID         Type  \
# 0      1399936       defect
# 1      1387208       defect
# 2      1368432       defect
# 3      1383741       defect
# 4      1388753       defect
# ...        ...          ...
# 38285  1734719         task
# 38286  1708329  enhancement
# 38287  1709129  enhancement
# 38288  1701347         task
# 38289  1742892         task
#
#                                                  Summary  Product  \
# 0      Shield unenrolls users in active preference ex...  Firefox
# 1      browser_as_load_location.js is permafailing on...  Firefox
# 2      web.skype.com is inaccessible: SEC_ERROR_OCSP_...  Firefox
# 3      Perma failure when 56 merge to beta in browser...  Firefox
# 4      Bookmarks and history pages in Library sub men...  Firefox
# ...                                                  ...      ...
# 38285  Fix test_bug1266815.html to work when download...  Firefox
# 38286  Update more of the icons in browser/themes/sha...  Firefox
# 38287  Downloads panel should auto open on download (...  Firefox
# 38288  Menulist chrome tests are unhappy with proton ...  Firefox
# 38289  Add UI for Fission-specific dom.ipc.processCou...  Firefox
#
#                         Component    Status Resolution              Updated  \
# 0                 Normandy Client  VERIFIED      FIXED  2018-01-27 11:10:40
# 1                    New Tab Page  RESOLVED      FIXED  2019-06-28 14:29:46
# 2                       Untriaged  RESOLVED  DUPLICATE  2017-05-29 04:49:00
# 3                     Preferences  RESOLVED      FIXED  2017-07-27 02:02:17
# 4      Toolbars and Customization  VERIFIED      FIXED  2017-09-22 10:09:03
# ...                           ...       ...        ...                  ...
# 38285             Downloads Panel  RESOLVED      FIXED  2021-10-12 02:34:06
# 38286                       Theme  VERIFIED      FIXED  2021-05-11 07:00:56
# 38287             Downloads Panel  RESOLVED      FIXED  2022-01-15 04:53:04
# 38288                       Theme  RESOLVED      FIXED  2021-03-27 13:57:58
# 38289                 Preferences  RESOLVED    WONTFIX  2021-12-17 11:14:11
#
#                                              Description  Duplicate_Bug_Ids
# 0      the activity stream team is conducting a study...                NaN
# 1      filed by  rvandermeulen  at  mozilla com     j...                NaN
# 2      user agent  mozilla       gecko   firefox     ...          1368433.0
# 3      found via uplift simulations   perma failure w...                NaN
# 4      user agent  mozilla       gecko   firefox     ...                NaN
# ...                                                  ...                ...
# 38285  this test needs the external application choos...                NaN
# 38286   browser themes shared icons back   svg    go ...                NaN
# 38287  created attachment   download   opened panel  ...                NaN
# 38288             mike kindly offered to look into this                 NaN
# 38289  if the fission experiment is active the user c...                NaN
#
# [38290 rows x 10 columns]

# %%
firefox_data.reset_index()
# Out:
#        index   Bug ID         Type  \
# 0          0  1399936       defect
# 1          1  1387208       defect
# 2          2  1368432       defect
# 3          3  1383741       defect
# 4          4  1388753       defect
# ...      ...      ...          ...
# 38285  38285  1734719         task
# 38286  38286  1708329  enhancement
# 38287  38287  1709129  enhancement
# 38288  38288  1701347         task
# 38289  38289  1742892         task
#
#                                                  Summary  Product  \
# 0      Shield unenrolls users in active preference ex...  Firefox
# 1      browser_as_load_location.js is permafailing on...  Firefox
# 2      web.skype.com is inaccessible: SEC_ERROR_OCSP_...  Firefox
# 3      Perma failure when 56 merge to beta in browser...  Firefox
# 4      Bookmarks and history pages in Library sub men...  Firefox
# ...                                                  ...      ...
# 38285  Fix test_bug1266815.html to work when download...  Firefox
# 38286  Update more of the icons in browser/themes/sha...  Firefox
# 38287  Downloads panel should auto open on download (...  Firefox
# 38288  Menulist chrome tests are unhappy with proton ...  Firefox
# 38289  Add UI for Fission-specific dom.ipc.processCou...  Firefox
#
#                         Component    Status Resolution              Updated  \
# 0                 Normandy Client  VERIFIED      FIXED  2018-01-27 11:10:40
# 1                    New Tab Page  RESOLVED      FIXED  2019-06-28 14:29:46
# 2                       Untriaged  RESOLVED  DUPLICATE  2017-05-29 04:49:00
# 3                     Preferences  RESOLVED      FIXED  2017-07-27 02:02:17
# 4      Toolbars and Customization  VERIFIED      FIXED  2017-09-22 10:09:03
# ...                           ...       ...        ...                  ...
# 38285             Downloads Panel  RESOLVED      FIXED  2021-10-12 02:34:06
# 38286                       Theme  VERIFIED      FIXED  2021-05-11 07:00:56
# 38287             Downloads Panel  RESOLVED      FIXED  2022-01-15 04:53:04
# 38288                       Theme  RESOLVED      FIXED  2021-03-27 13:57:58
# 38289                 Preferences  RESOLVED    WONTFIX  2021-12-17 11:14:11
#
#                                              Description  Duplicate_Bug_Ids
# 0      the activity stream team is conducting a study...                NaN
# 1      filed by  rvandermeulen  at  mozilla com     j...                NaN
# 2      user agent  mozilla       gecko   firefox     ...          1368433.0
# 3      found via uplift simulations   perma failure w...                NaN
# 4      user agent  mozilla       gecko   firefox     ...                NaN
# ...                                                  ...                ...
# 38285  this test needs the external application choos...                NaN
# 38286   browser themes shared icons back   svg    go ...                NaN
# 38287  created attachment   download   opened panel  ...                NaN
# 38288             mike kindly offered to look into this                 NaN
# 38289  if the fission experiment is active the user c...                NaN
#
# [38290 rows x 11 columns]

# %%
firefox_data = firefox_data.drop_duplicates()

# %%
firefox_data
# Out:
#         Bug ID         Type  \
# 0      1399936       defect
# 1      1387208       defect
# 2      1368432       defect
# 3      1383741       defect
# 4      1388753       defect
# ...        ...          ...
# 38285  1734719         task
# 38286  1708329  enhancement
# 38287  1709129  enhancement
# 38288  1701347         task
# 38289  1742892         task
#
#                                                  Summary  Product  \
# 0      Shield unenrolls users in active preference ex...  Firefox
# 1      browser_as_load_location.js is permafailing on...  Firefox
# 2      web.skype.com is inaccessible: SEC_ERROR_OCSP_...  Firefox
# 3      Perma failure when 56 merge to beta in browser...  Firefox
# 4      Bookmarks and history pages in Library sub men...  Firefox
# ...                                                  ...      ...
# 38285  Fix test_bug1266815.html to work when download...  Firefox
# 38286  Update more of the icons in browser/themes/sha...  Firefox
# 38287  Downloads panel should auto open on download (...  Firefox
# 38288  Menulist chrome tests are unhappy with proton ...  Firefox
# 38289  Add UI for Fission-specific dom.ipc.processCou...  Firefox
#
#                         Component    Status Resolution              Updated  \
# 0                 Normandy Client  VERIFIED      FIXED  2018-01-27 11:10:40
# 1                    New Tab Page  RESOLVED      FIXED  2019-06-28 14:29:46
# 2                       Untriaged  RESOLVED  DUPLICATE  2017-05-29 04:49:00
# 3                     Preferences  RESOLVED      FIXED  2017-07-27 02:02:17
# 4      Toolbars and Customization  VERIFIED      FIXED  2017-09-22 10:09:03
# ...                           ...       ...        ...                  ...
# 38285             Downloads Panel  RESOLVED      FIXED  2021-10-12 02:34:06
# 38286                       Theme  VERIFIED      FIXED  2021-05-11 07:00:56
# 38287             Downloads Panel  RESOLVED      FIXED  2022-01-15 04:53:04
# 38288                       Theme  RESOLVED      FIXED  2021-03-27 13:57:58
# 38289                 Preferences  RESOLVED    WONTFIX  2021-12-17 11:14:11
#
#                                              Description  Duplicate_Bug_Ids
# 0      the activity stream team is conducting a study...                NaN
# 1      filed by  rvandermeulen  at  mozilla com     j...                NaN
# 2      user agent  mozilla       gecko   firefox     ...          1368433.0
# 3      found via uplift simulations   perma failure w...                NaN
# 4      user agent  mozilla       gecko   firefox     ...                NaN
# ...                                                  ...                ...
# 38285  this test needs the external application choos...                NaN
# 38286   browser themes shared icons back   svg    go ...                NaN
# 38287  created attachment   download   opened panel  ...                NaN
# 38288             mike kindly offered to look into this                 NaN
# 38289  if the fission experiment is active the user c...                NaN
#
# [38290 rows x 10 columns]

# %%
firefox_data = firefox_data.dropna(axis=0, subset=['Bug ID'])

# %%
firefox_data.info()

# %% [markdown]
# ## On complete JDT data

# %%
firefox_data["Description"]= firefox_data["Description"].str.replace("fixed in HEAD", "", case = False)
firefox_data["Description"]= firefox_data["Description"].str.replace("has been marked as readonly", " ", case = False)

# %%
#Text Cleaning round 1 (removing punctutions)


def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
#     print(text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('\w*\f\w*', '', text)
    text = re.sub('\(.*?\)', '', text)
    text = re.sub('\[.*]\)', '', text)
    text = text.lower()
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    return text

round1 = lambda x: clean_text_round1(x)

# %%
firefox_data.info()

# %%
firefox_data = firefox_data.dropna(axis=0, subset=['Description'])

# %%
firefox_data['Description'] = firefox_data['Description'].apply(clean_text_round1)

# %%
# Apply a second round of cleaning (removing punctuations)
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\t', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
firefox_data['Description'] = firefox_data['Description'].apply(clean_text_round2)

# %%
def lemmatize(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 5:
            result.append(lemmatize(token))
    return result

# %%
firefox_data['Description'] = firefox_data['Description'].map(preprocess)

# %%
firefox_data['Duplicate_Bug_Ids'].isnull().sum()
# Out:
# 30431

# %%
#Saving all the duplicate reports into a csv file as a testing set
duplicate_reports = firefox_data.dropna(axis=0, subset=['Duplicate_Bug_Ids'])
duplicate_reports.reset_index(drop=True)
duplicate_reports.to_csv('firefox_duplicate_reports.csv')

# %%
#Seperating all the master reports into a dataframe
master_reports = firefox_data[firefox_data.isnull().any(axis=1)]
master_reports.reset_index(drop=True)
# Out:
#         Bug ID         Type  \
# 0      1399936       defect
# 1      1387208       defect
# 2      1383741       defect
# 3      1388753       defect
# 4      1390006       defect
# ...        ...          ...
# 30426  1734719         task
# 30427  1708329  enhancement
# 30428  1709129  enhancement
# 30429  1701347         task
# 30430  1742892         task
#
#                                                  Summary  Product  \
# 0      Shield unenrolls users in active preference ex...  Firefox
# 1      browser_as_load_location.js is permafailing on...  Firefox
# 2      Perma failure when 56 merge to beta in browser...  Firefox
# 3      Bookmarks and history pages in Library sub men...  Firefox
# 4      browser_BrowserUITelemetry_defaults.js is goin...  Firefox
# ...                                                  ...      ...
# 30426  Fix test_bug1266815.html to work when download...  Firefox
# 30427  Update more of the icons in browser/themes/sha...  Firefox
# 30428  Downloads panel should auto open on download (...  Firefox
# 30429  Menulist chrome tests are unhappy with proton ...  Firefox
# 30430  Add UI for Fission-specific dom.ipc.processCou...  Firefox
#
#                         Component    Status Resolution              Updated  \
# 0                 Normandy Client  VERIFIED      FIXED  2018-01-27 11:10:40
# 1                    New Tab Page  RESOLVED      FIXED  2019-06-28 14:29:46
# 2                     Preferences  RESOLVED      FIXED  2017-07-27 02:02:17
# 3      Toolbars and Customization  VERIFIED      FIXED  2017-09-22 10:09:03
# 4      Toolbars and Customization  VERIFIED      FIXED  2017-08-29 02:56:46
# ...                           ...       ...        ...                  ...
# 30426             Downloads Panel  RESOLVED      FIXED  2021-10-12 02:34:06
# 30427                       Theme  VERIFIED      FIXED  2021-05-11 07:00:56
# 30428             Downloads Panel  RESOLVED      FIXED  2022-01-15 04:53:04
# 30429                       Theme  RESOLVED      FIXED  2021-03-27 13:57:58
# 30430                 Preferences  RESOLVED    WONTFIX  2021-12-17 11:14:11
#
#                                              Description  Duplicate_Bug_Ids
# 0      [activity, stream, conduct, shield, mechanism,...                NaN
# 1      [rvandermeulen, mozilla, mozilla, artifacts, p...                NaN
# 2      [uplift, simulations, failure, unexpected, too...                NaN
# 3      [mozilla, firefox, reproduce, hamburger, libra...                NaN
# 4      [track, request, release, permafailing, devedi...                NaN
# ...                                                  ...                ...
# 30426  [external, application, chooser, dialog, appea...                NaN
# 30427  [browser, theme, share, track, protection, blo...                NaN
# 30428  [create, attachment, download, open, expect, d...                NaN
# 30429                                    [kindly, offer]                NaN
# 30430  [fission, experiment, active, longer, change, ...                NaN
#
# [30431 rows x 10 columns]

# %%
master_reports.Description.isna().sum()
# Out:
# 0

# %%
#Removing empty master_reports after data cleaning process
mr = pd.DataFrame()
count = 0
for i in range(len(master_reports)):
    if(len(master_reports.Description.iloc[i])>2):
        mr= mr.append(master_reports.iloc[[i]])
        count=+1

# %%
master_reports.to_csv('firefox_master_reports.csv')

# %%
#importing the CSV file ofxzaZ8Z the master reports from google drive into a dataframe
master_reports = pd.read_csv('firefox_master_reports.csv')
master_reports = master_reports.drop(columns=['Unnamed: 0'])

# %%
master_reports['Description'] = master_reports['Description'].map(preprocess)

# %%
#Creating a dictionary using gensim library
dictionary = gensim.corpora.Dictionary(master_reports['Description'])
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
#Print top 20 words from the dictionary
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 20:
        break
# Out:
# 0 activity
# 1 approach
# 2 centre
# 3 collection
# 4 control
# 5 decrease
# 6 deployment
# 7 directly
# 8 enable
# 9 enrollment
# 10 independent
# 11 indicate
# 12 mechanism
# 13 number
# 14 obvious
# 15 perspective
# 16 population
# 17 problem
# 18 reason
# 19 relate
# 20 shield

# %%
#Creating BoW using the the dictionary
bow_corpus = [dictionary.doc2bow(doc) for doc in master_reports['Description']]

# %%
#Printing the BoW for single document
bow_doc_8 = bow_corpus[8]
for i in range(len(bow_doc_8)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_8[i][0], 
                                               dictionary[bow_doc_8[i][0]], 
bow_doc_8[i][1]))

# %%
# open a file, where you stored the pickled data
f= open('firefox_bow_corpus.pickle', 'wb')

# dump information to that file
pickle.dump(bow_corpus, f)

# %%
#open a file, where you stored the pickled data
file = open('firefox_dictionary.pickle', 'wb')

# dump information to that file
pickle.dump(dictionary, file)

# %%
#Preparing the parameters for LDA model
corpus = bow_corpus
no_of_topics = 10
dictionary = dictionary
p = 20
k = 2
epochs = 100

#Training the LDA model on the BoW corpus
lda_model = gensim.models.LdaMulticore(corpus, num_topics=no_of_topics, id2word=dictionary, passes=p, workers=k, iterations=epochs)

# %%
# save model to disk (no need to use pickle module)
lda_model.save('firefox_lda_model.model')

# %%
# Printing the topics and the propability distributions of words in those topics
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))

# %%
#Let's evaluate the model using Perplexity and Coherence Bag of words- Title

# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(bow_corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=firefox_data['Description'], dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -5.44098279167943
#
# Coherence Score:  0.559187831951582

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, bow_corpus, dictionary)
vis
# Out:
# /local/pkg/python/root-python-3.7/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /users/grad/umukherjee/.local/lib/python3.7/site-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 5     -0.261531 -0.201130       1        1  15.490991
# 8      0.212846 -0.004278       2        1  15.346575
# 4     -0.182028 -0.256699       3        1  12.699372
# 1      0.244743 -0.125587       4        1  11.273365
# 9      0.173683  0.069186       5        1  10.314432
# 7     -0.197741  0.147313       6        1   8.024364
# 0     -0.115625  0.169589       7        1   7.872010
# 3     -0.139049  0.161397       8        1   7.366817
# 2      0.229847 -0.050867       9        1   6.186777
# 6      0.034856  0.091076      10        1   5.425297, topic_info=           Term          Freq         Total Category  logprob  loglift
# 31      browser  89169.000000  89169.000000  Default  30.0000  30.0000
# 56      content  31720.000000  31720.000000  Default  29.0000  29.0000
# 868      thread  14971.000000  14971.000000  Default  28.0000  28.0000
# 125  components  20181.000000  20181.000000  Default  27.0000  27.0000
# 44      firefox  29889.000000  29889.000000  Default  26.0000  26.0000
# ..          ...           ...           ...      ...      ...      ...
# 31      browser   1117.440959  89169.334609  Topic10  -4.0993  -1.4654
# 435     disable    487.489189   3110.824587  Topic10  -4.9288   1.0607
# 743      status    416.104258   1721.624395  Topic10  -5.0871   1.4940
# 69       create    453.946581  10410.408323  Topic10  -5.0001  -0.2185
# 322     service    408.555653   6163.171590  Topic10  -5.1054   0.2004
#
# [693 rows x 6 columns], token_table=      Topic      Freq            Term
# term
# 2095     10  0.997413  aboutcerterror
# 2607      3  0.990753     aboutconfig
# 2647      3  0.998221     aboutlogins
# 2211     10  0.994972     aboutnewtab
# 2543      4  0.023522    aboutwelcome
# ...     ...       ...             ...
# 1794      3  0.930958      xulelement
# 1945      7  0.997878        xulstore
# 448       2  0.884944         youtube
# 448       4  0.112593         youtube
# 994       8  0.999358     zombiecheck
#
# [1500 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 9, 5, 2, 10, 8, 1, 4, 3, 7])

# %%
#Creating 10 empty clusters and pushing master reports in each of them based on topic modeling and saving them in individual csv file
for c in range(10):
    exec('topic_{} = pd.DataFrame()'.format(c))
    for i in range(len(master_reports)):
        topic=lda_model[dictionary.doc2bow(master_reports.Description[i])]
        topic= np.asarray(topic)
        if int(topic[np.argmax(topic[:,1]),0])== c:
            exec('topic_{} = topic_{}.append(master_reports.loc[[i]])'.format(c,c))
            exec('topic_{} = topic_{}.reset_index(drop=True)'.format(c,c))
            exec('topic_{}.to_csv("topic_{}.csv")'.format(c,c))

# %%
# open a file, where you stored the pickled data
f = open('firefox_bow_corpus.pickle', 'rb')
bow_corpus=pickle.load(f)

file = open('firefox_dictionary.pickle', 'rb')
dictionary=pickle.load(file)

# later on, load trained model from file
lda_model =  models.LdaModel.load('firefox_lda_model.model')

# %%
#Import all the clusters from the drive 
for c in range(10):
    exec('topic_{} = pd.read_csv("topic_{}.csv")'.format(c,c))
    exec("topic_{}= topic_{}.drop(columns=['Unnamed: 0'])".format(c,c))
    exec("topic_{}['Description'] = topic_{}['Description'].map(preprocess)".format(c,c))

# %%
for sent in range(10):
    exec('print(len(sent_{}))'.format(sent))

# %%
#Training GloVe model for each cluster
for cluster in range(10):
    vector_size = 100
    exec('glove_corpus{}=Corpus()'.format(cluster, cluster)) 
    exec('glove_corpus{}.fit(sent_{})'.format(cluster, cluster))
    exec('glove{}= Glove(no_components=vector_size, learning_rate=0.18, alpha=0.75, max_count=100, max_loss=10.0, random_state=None)'.format(cluster, cluster))
    exec('glove{}.fit(glove_corpus{}.matrix, epochs=1000, no_threads=3, verbose=True)'.format(cluster, cluster))
    exec('transformer = lambda dictionary2:glove{}.transform_paragraph(words, epochs=1000,ignore_missing=False)'.format(cluster, cluster))
    exec('glove{}.add_dictionary(glove_corpus{}.dictionary)'.format(cluster, cluster))

    #Save the all the models in individual file
    exec('path = get_tmpfile("glove{}.model")'.format(cluster))
    exec('glove{}.save("glove{}.model")'.format(cluster, cluster))

# %% [markdown]
# ## Classification

# %%
# importing all the clusters created using LDA based topic modeling
for c in range(10):
    exec('topic_{} = pd.read_csv("topic_{}.csv")'.format(c,c))
    exec("topic_{}= topic_{}.drop(columns=['Unnamed: 0'])".format(c,c))
    exec("topic_{}['Description'] = topic_{}['Description'].map(preprocess)".format(c,c))

# %%
#import the duplicate reports for testing purpose
test = pd.read_csv('firefox_duplicate_reports.csv')
test = test.drop(columns=['Unnamed: 0'])

# %%
test
# Out:
#        Bug ID    Type                                            Summary  \
# 0     1368432  defect  web.skype.com is inaccessible: SEC_ERROR_OCSP_...
# 1     1337204  defect  Mozilla Firefox 51.0.1 uses a lot of memory wi...
# 2     1396728  defect  Windows 7 professional 64bit running Fx 51.0.1...
# 3     1368321  defect  Firefox version 53.0.3 appears high memory, hi...
# 4     1340122  defect  List box (or) Drop-down box background color n...
# ...       ...     ...                                                ...
# 7854  1724390  defect  Option to add the already added click search e...
# 7855  1713309  defect  Add search engine: Yandex icon design changes ...
# 7856  1747252  defect  [macOS] Tab border is black with certain custo...
# 7857  1717820  defect  [XFA] A string is displayed as double-underlin...
# 7858  1723406  defect  Intermittent browser/components/preferences/te...
#
#       Product                Component    Status Resolution  \
# 0     Firefox                Untriaged  RESOLVED  DUPLICATE
# 1     Firefox  Extension Compatibility  RESOLVED  DUPLICATE
# 2     Firefox                Migration  RESOLVED  DUPLICATE
# 3     Firefox                Untriaged  RESOLVED  DUPLICATE
# 4     Firefox                Untriaged  RESOLVED  DUPLICATE
# ...       ...                      ...       ...        ...
# 7854  Firefox                   Search  RESOLVED  DUPLICATE
# 7855  Firefox                   Search  RESOLVED  DUPLICATE
# 7856  Firefox                    Theme  RESOLVED  DUPLICATE
# 7857  Firefox               PDF Viewer  RESOLVED  DUPLICATE
# 7858  Firefox              Preferences  RESOLVED  DUPLICATE
#
#                   Updated                                        Description  \
# 0     2017-05-29 04:49:00  ['mozilla', 'firefox', 'reproduce', 'actual', ...
# 1     2017-07-05 11:48:47  ['mozilla', 'firefox', 'reproduce', 'cleanup',...
# 2     2017-09-19 16:35:17  ['mozilla', 'firefox', 'reproduce', 'firefox',...
# 3     2017-07-05 11:45:21  ['mozilla', 'firefox', 'reproduce', 'mozilla',...
# 4     2017-02-16 04:31:51  ['mozilla', 'firefox', 'reproduce', 'have', 'v...
# ...                   ...                                                ...
# 7854  2021-08-06 04:40:51  ['create', 'attachment', 'searchengine', 'affe...
# 7855  2021-06-07 00:35:39  ['create', 'attachment', 'affect', 'ubuntu', '...
# 7856  2022-01-25 12:01:42  ['create', 'attachment', 'affect', 'versions',...
# 7857  2021-07-08 05:45:39  ['create', 'attachment', 'specific', 'scroll',...
# 7858  2021-08-02 08:19:52  ['malexandru', 'mozilla', 'parse', 'autoland',...
#
#       Duplicate_Bug_Ids
# 0             1368433.0
# 1             1346556.0
# 2             1352458.0
# 3             1346556.0
# 4              910022.0
# ...                 ...
# 7854          1457069.0
# 7855          1457069.0
# 7856          1746000.0
# 7857          1716833.0
# 7858          1717917.0
#
# [7859 rows x 10 columns]

# %%
def lemmatize2(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')

def preprocess2(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 5:
            result.append(lemmatize(token))
    return result

# %%
test['Description']= test['Description'].fillna('').astype(str).map(preprocess2)

# %%
for mod in range(10):   
    #import all the trained GloVe models
    exec('glove{} = Glove.load("glove{}.model")'.format(mod, mod))

# %%
#This will return the index of cluster in which the master report of duplicate report may reside
def sim_with_clusters_lda_topn(DR, n):
    vec_bow = dictionary.doc2bow(DR)
    x= lda_model[vec_bow]
    topic = np.asarray(x)
    # max_sim = int(topic[np.argmax(topic[:,1]),0]) 
    # max_sim
    sim=[]
    x= topic[np.argsort(topic[:,1])[-n:][::-1],0]
    for i in range(len(x)):
        sim.append(int(x[i]))
    # return max_sim
    return sim

# %%
# Convert multiple word embeddings into a single document vector by averaging the word embeddings by GloVe model

def average_word_vectors_glove(words, model, vocabulary, num_features):  
    feature_vector = np.zeros((num_features,),dtype="float64")
    nwords = 0.  

    for word in words:
        if word in vocabulary: 
            nwords = nwords + 1.
            feature_vector = np.add(feature_vector, model.wv[model.wv.key_to_index[word]])

    if nwords:
        feature_vector = np.divide(feature_vector, nwords)
        
    return feature_vector
    


def averaged_word_vectorizer_glove(corpus, model, num_features):
    vocabulary = set(model.wv.key_to_index)
    if(any(isinstance(i, list) for i in corpus)):
        features = [average_word_vectors_glove(tokenized_sentence, model, vocabulary, num_features)
                      for tokenized_sentence in corpus]
        return np.array(features)
    else:
          features = average_word_vectors_glove(corpus, model, vocabulary, num_features)
    return np.array(features)

# %%
# Similarity between two feature vectors using the average of cosine similarity and euclidean similarity
def sim(vec1, vec2): 
    sim1 = 1/(1+distance.euclidean(vec1, vec2))
    sim2 = cosine_similarity(vec1, vec2)
    sim=(sim1+sim2)/2 
    return sim

# %%
# Different kinds of fusion of two master report feature vectors and two duplicate report feature vectors
def fusion(vec1, vec2, vec3, vec4, fusion_no):

    # fusion_no = 1 : concatenation of the vectors
    if (fusion_no == '1'):
        master = np.concatenate((vec1, vec2), axis=1)
        vec_duplicate = np.concatenate((vec3, vec4), axis=0)
        vec_duplicate=[vec_duplicate]
        return vec_duplicate, master

    #fusion_no = 2 : average of the vectors
    elif (fusion_no == '2'):
        vec3 = [vec3]
        vec4 = [vec4]
        avg1 = (np.add(vec1, vec2))/2
        avg2 = (np.add(vec3, vec4))/2
        return avg2, avg1

    #fusion_no = 3 : Dimensionality reduction using PCA on concatenation of the vectors
    elif (fusion_no == '3'):
        master = np.concatenate((vec1, vec2), axis=1)
        pca = PCA(n_components=100)
        avg_fit = pca.fit(master)
        master = pca.transform(master)
        vec_duplicate = np.concatenate((vec3, vec4), axis=0)
        vec_duplicate=[vec_duplicate]
        vec_duplicate = pca.transform(vec_duplicate)
        return vec_duplicate, master

    #fusion_no = 3 : Dimensionality reduction using PCA on average of the vectors
    elif (fusion_no == '4'):
        vec3 = [vec3]
        vec4 = [vec4]
        avg1 = (np.add(vec1, vec2))/2
        pca = PCA(n_components=100)
        avg_fit = pca.fit(avg1)
        master = pca.transform(avg1)
        avg2 = (np.add(vec3, vec4))/2
        vec_duplicate = pca.transform(avg2)
        return vec_duplicate, master

    else:
        raise ValueError('Invalid value for fusion')

# %%
# creation of feature vectors by multimodality feature extraction
def feature_vectors_multi_modality(DR, corpus, model1, model2, fusion_no):
    master_ft1 = averaged_word_vectorizer_w2v(corpus=sent, model=model1, num_features=100)
    master_glove2 = averaged_word_vectorizer_glove(corpus=sent, model=model2, num_features=100)

    vec_duplicate1 = averaged_word_vectorizer_w2v(corpus=DR, model=model1, num_features=100)
    vec_duplicate2 = averaged_word_vectorizer_glove(corpus=DR, model=model2, num_features=100)

    vec_duplicate , master= fusion(master_glove2,vec_duplicate2, fusion_no)
    return vec_duplicate,master

# %%
# creation of feature vectors by singlemodality feature extraction
def feature_vectors_single_modality(DR, corpus, model1):
    master = averaged_word_vectorizer_glove(corpus=sent, model=model1, num_features=100)

    vec_duplicate = averaged_word_vectorizer_glove(corpus=DR, model=model1, num_features=100)

    vec_duplicate = [vec_duplicate]

    return vec_duplicate, master

# %%
import time
# Recall Rate for Top-2.5K reports (Because Top-N where N = n * topn (2.5K = 3*833)) 
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(10)

# %%
test
# Out:
#        Bug ID    Type                                            Summary  \
# 0     1368432  defect  web.skype.com is inaccessible: SEC_ERROR_OCSP_...
# 1     1337204  defect  Mozilla Firefox 51.0.1 uses a lot of memory wi...
# 2     1396728  defect  Windows 7 professional 64bit running Fx 51.0.1...
# 3     1368321  defect  Firefox version 53.0.3 appears high memory, hi...
# 4     1340122  defect  List box (or) Drop-down box background color n...
# ...       ...     ...                                                ...
# 7854  1724390  defect  Option to add the already added click search e...
# 7855  1713309  defect  Add search engine: Yandex icon design changes ...
# 7856  1747252  defect  [macOS] Tab border is black with certain custo...
# 7857  1717820  defect  [XFA] A string is displayed as double-underlin...
# 7858  1723406  defect  Intermittent browser/components/preferences/te...
#
#       Product                Component    Status Resolution  \
# 0     Firefox                Untriaged  RESOLVED  DUPLICATE
# 1     Firefox  Extension Compatibility  RESOLVED  DUPLICATE
# 2     Firefox                Migration  RESOLVED  DUPLICATE
# 3     Firefox                Untriaged  RESOLVED  DUPLICATE
# 4     Firefox                Untriaged  RESOLVED  DUPLICATE
# ...       ...                      ...       ...        ...
# 7854  Firefox                   Search  RESOLVED  DUPLICATE
# 7855  Firefox                   Search  RESOLVED  DUPLICATE
# 7856  Firefox                    Theme  RESOLVED  DUPLICATE
# 7857  Firefox               PDF Viewer  RESOLVED  DUPLICATE
# 7858  Firefox              Preferences  RESOLVED  DUPLICATE
#
#                   Updated                                        Description  \
# 0     2017-05-29 04:49:00  [mozilla, firefox, reproduce, actual, result, ...
# 1     2017-07-05 11:48:47  [mozilla, firefox, reproduce, cleanup, memory,...
# 2     2017-09-19 16:35:17  [mozilla, firefox, reproduce, firefox, windows...
# 3     2017-07-05 11:45:21  [mozilla, firefox, reproduce, mozilla, resourc...
# 4     2017-02-16 04:31:51  [mozilla, firefox, reproduce, background, opti...
# ...                   ...                                                ...
# 7854  2021-08-06 04:40:51  [create, attachment, searchengine, affect, ver...
# 7855  2021-06-07 00:35:39  [create, attachment, affect, ubuntu, windows, ...
# 7856  2022-01-25 12:01:42  [create, attachment, affect, versions, affect,...
# 7857  2021-07-08 05:45:39  [create, attachment, specific, scroll, notice,...
# 7858  2021-08-02 08:19:52  [malexandru, mozilla, autoland, service, mozil...
#
#       Duplicate_Bug_Ids
# 0             1368433.0
# 1             1346556.0
# 2             1352458.0
# 3             1346556.0
# 4              910022.0
# ...                 ...
# 7854          1457069.0
# 7855          1457069.0
# 7856          1746000.0
# 7857          1716833.0
# 7858          1717917.0
#
# [7859 rows x 10 columns]

# %%
test = test.rename(columns={'Bug ID':'Bug_ID'})

# %%
def compare_topn(model1, cluster, sent, DR, topn, modal):
    similarity=[]
    if (modal == 'single'):
        vec_duplicate, master= feature_vectors_single_modality(DR, sent, model1)

    else:
        raise ValueError('Invalid Modality entered')

    for doc in range(len(master)):
        vec_master = master[doc]
        vec_master= [vec_master]
        unified_sim = sim(vec_duplicate, vec_master)

        similarity.append(unified_sim)
    similarity = np.asarray(similarity)
    similarity= np.concatenate(similarity, axis=0 )
    similarity= np.concatenate(similarity, axis=0 )
    max_similar_reports=similarity.argsort()[-topn:][::-1][1:]
    
    return(max_similar_reports)

# %% [markdown]
# ## LDA and GLOVE

# %% [markdown]
# #### on testset

# %%
#Returns Top-N master reports
dup_id = test.Duplicate_Bug_Ids
def compare_topn2(model1, cluster, sent, DR, topn, modal):
    similarity=[]
    if (modal == 'single'):
        vec_duplicate, master= feature_vectors_single_modality2(DR, sent, model1)

    else:
        raise ValueError('Invalid Modality entered')

    for doc in range(len(master)):
        vec_master = master[doc]
        vec_master= [vec_master]
        unified_sim = sim(vec_duplicate, vec_master)

        similarity.append(unified_sim)
    similarity = np.asarray(similarity)
    similarity= np.concatenate(similarity, axis=0 )
    similarity= np.concatenate(similarity, axis=0 )
    max_similar_reports=similarity.argsort()[-topn:][::-1]
    return(max_similar_reports)

# %%
# creation of feature vectors by singlemodality feature extraction
def feature_vectors_single_modality2(DR, corpus, model1):
    master = averaged_word_vectorizer_glove2(corpus=sent, model=model1, num_features=100)

    vec_duplicate = averaged_word_vectorizer_glove2(corpus=DR, model=model1, num_features=100)

    vec_duplicate = [vec_duplicate]

    return vec_duplicate, master

# %%
def average_word_vectors_glove2(words, model, vocabulary, num_features):  
    feature_vector = np.zeros((num_features,),dtype="float64")
    nwords = 0.  

    for word in words:
        if word in vocabulary: 
            nwords = nwords + 1.
            feature_vector = np.add(feature_vector, model.word_vectors[model.dictionary[word]])

    if nwords:
        feature_vector = np.divide(feature_vector, nwords)
        
    return feature_vector
def averaged_word_vectorizer_glove2(corpus, model, num_features):
    vocabulary = set(model.dictionary)
    if(any(isinstance(i, list) for i in corpus)):
        features = [average_word_vectors_glove2(tokenized_sentence, model, vocabulary, num_features)
                      for tokenized_sentence in corpus]
        return np.array(features)
    else:
          features = average_word_vectors_glove2(corpus, model, vocabulary, num_features)
    return np.array(features)

# %%
#top 1
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 1
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 1                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 5
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 1                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 10
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 3                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 20
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 6                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 25
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 8                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 30
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 10                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 50
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 16                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 75
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 25                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 100
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 33                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %% [markdown]
# ## On Textually Similar and Dissimilar Dataset

# %%
# importing all the clusters created using LDA based topic modeling
for c in range(10):
    exec('topic_{} = pd.read_csv("topic_{}.csv")'.format(c,c))
    exec("topic_{}= topic_{}.drop(columns=['Unnamed: 0'])".format(c,c))
    exec("topic_{}['Description'] = topic_{}['Description'].map(preprocess2)".format(c,c))

# %%
def lemmatize2(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')

def preprocess2(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 5:
            result.append(lemmatize2(token))
    return result

#import the duplicate reports for testing purpose
test_sim = pd.read_csv('firefox_textually_similar_duplicates_new.csv')
# test_sim = test_sim.drop(columns=['Unnamed: 0'])

#import the duplicate reports for testing purpose
test_dissim = pd.read_csv('firefox_textually_dissimilar_duplicates_new.csv')
# test_dissim = test_dissim.drop(columns=['Unnamed: 0'])

test_sim['Description']= test_sim['Description'].fillna('').astype(str).map(preprocess2)
test_dissim['Description']= test_dissim['Description'].fillna('').astype(str).map(preprocess2)

# %%
def lemmatize2(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')

def preprocess2(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 5:
            result.append(lemmatize2(token))
    return result

# %%
test_dissim['Description']= test_dissim['Description'].fillna('').astype(str).map(preprocess2)

# %%
test_sim['Description']= test_sim['Description'].fillna('').astype(str).map(preprocess2)

# %%
test_dissim["Bug_Id"] = test_dissim["Bug_Id"].astype("float64")

# %%
test_sim["Bug_Id"] = test_sim["Bug_Id"].astype("float64")

# %%
nan_value = float("NaN")
test_sim.replace("", nan_value, inplace=True)
test_sim.dropna(subset = ["Duplicate_Bug_Ids"], inplace=True)

# %%
nan_value = float("NaN")
test_dissim.replace("", nan_value, inplace=True)
test_dissim.dropna(subset = ["Duplicate_Bug_Ids"], inplace=True)

# %%
cond = (test_sim['Duplicate_Bug_Ids'] == 'NaN')
cond.unique()
# Out:
# array([False])

# %%
cond = (test_dissim['Duplicate_Bug_Ids'] == 'NaN')
cond.unique()
# Out:
# array([False])

# %%
test_sim = test_sim.reset_index(drop=True)

# %%
test_dissim = test_dissim.reset_index(drop=True)

# %% [markdown]
# # Textually Similar

# %%
#top1
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 1
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 1                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top5
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 1                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top10
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 3                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top20
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 6                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 25
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 8                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top30
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 10                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top50
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 16                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top75
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 25                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top100
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 33                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %% [markdown]
# # Textually Dissimilar

# %%
#top1
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 1
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 1                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top5
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 1                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top10
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 3                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top20
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 6                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top25
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 8                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top30
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 10                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top50
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 16                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top75
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 25                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top100
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 33                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")

# %%
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")
