# %%
import pandas as pd
import nltk
import gensim
from gensim.utils import simple_preprocess
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from gensim.parsing.preprocessing import STOPWORDS
import numpy as np
import pickle
nltk.download('stopwords')
nltk.download('wordnet')
import re
import string

# %%
from scipy.spatial import distance
import pandas as pd
import nltk
import gensim
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from gensim.parsing.preprocessing import STOPWORDS
import numpy as np
from gensim import corpora,models
import time
import pickle
nltk.download('stopwords')
nltk.download('wordnet')
from sklearn.metrics.pairwise import cosine_similarity
import warnings
from gensim.models import Word2Vec,FastText
from sklearn.decomposition import PCA
from scipy.spatial import distance
warnings.filterwarnings("ignore", category=DeprecationWarning)
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# %%
from gensim import corpora,models

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from gensim.models import Word2Vec,FastText
from gensim.test.utils import get_tmpfile
from glove import Glove, Corpus

# %%
mobile_data=pd.read_csv('mobile_preproccessed_whole_dataset.csv')
mobile_data.tail()
# Out:
#       Unnamed: 0   Bug ID    Type  \
# 5315        5499  1683643  defect
# 5316        5500  1649160  defect
# 5317        5501  1514619  defect
# 5318        5502  1546822  defect
# 5319        5503  1728461  defect
#
#                                                 Summary          Product  \
# 5315  Intermittent org.mozilla.geckoview.test.Select...        GeckoView
# 5316  Download Feature: unicode RTLO char can fake t...  Firefox for iOS
# 5317  Menu options are in different order than new t...  Firefox for iOS
# 5318  Notifications repeating if not acted on in iOS...  Firefox for iOS
# 5319  GeckoView unconditionally clears the startup c...        GeckoView
#
#              Component    Status  Resolution              Updated   Bug Id  \
# 5315           General  RESOLVED   DUPLICATE  2021-07-30 19:04:17  1683643
# 5316           General  RESOLVED       FIXED  2020-12-18 17:20:48  1649160
# 5317  Menu and Toolbar  RESOLVED     INVALID  2019-02-11 16:36:05  1514619
# 5318              Sync  RESOLVED  WORKSFORME  2019-09-18 10:10:20  1546822
# 5319           General  RESOLVED       FIXED  2021-09-20 10:02:49  1728461
#
#                                             Description  Duplicate_Bug_Ids
# 5315    filed by    rmaries  at  mozilla com   parse...          1682775.0
# 5316  created attachment   regedt‮gpj exe  summary  ...                NaN
# 5317  created attachment             png  the hostor...                NaN
# 5318  created attachment   syncnotificationecho png ...                NaN
# 5319  on the moto   in fenix  we spend     in  inter...                NaN

# %%
mobile_data = mobile_data.reset_index()
mobile_data
# Out:
#       index  Unnamed: 0   Bug ID         Type  \
# 0         0           0  1668376       defect
# 1         1           1  1631754       defect
# 2         2           2  1677838       defect
# 3         3           4  1686100  enhancement
# 4         4           5  1630229       defect
# ...     ...         ...      ...          ...
# 5315   5315        5499  1683643       defect
# 5316   5316        5500  1649160       defect
# 5317   5317        5501  1514619       defect
# 5318   5318        5502  1546822       defect
# 5319   5319        5503  1728461       defect
#
#                                                 Summary          Product  \
# 0     Test failure in dom/base/test/test_window_clos...        GeckoView
# 1     PanZoomController erroneously returns INPUT_RE...        GeckoView
# 2     NumberFormatExceptionjava.lang.Integer in pars...        GeckoView
# 3     Route Service.onTrimMemory notifications throu...        GeckoView
# 4     Crash in [@ java.lang.AssertionError: at org.m...        GeckoView
# ...                                                 ...              ...
# 5315  Intermittent org.mozilla.geckoview.test.Select...        GeckoView
# 5316  Download Feature: unicode RTLO char can fake t...  Firefox for iOS
# 5317  Menu options are in different order than new t...  Firefox for iOS
# 5318  Notifications repeating if not acted on in iOS...  Firefox for iOS
# 5319  GeckoView unconditionally clears the startup c...        GeckoView
#
#              Component    Status  Resolution              Updated   Bug Id  \
# 0              General  RESOLVED       FIXED  2020-10-14 03:01:38  1668376
# 1              General  RESOLVED       FIXED  2020-05-23 04:47:46  1631754
# 2              General  RESOLVED       FIXED  2021-01-06 13:28:48  1677838
# 3              General  RESOLVED       FIXED  2021-01-12 02:17:23  1686100
# 4              General  RESOLVED       FIXED  2020-05-28 05:17:09  1630229
# ...                ...       ...         ...                  ...      ...
# 5315           General  RESOLVED   DUPLICATE  2021-07-30 19:04:17  1683643
# 5316           General  RESOLVED       FIXED  2020-12-18 17:20:48  1649160
# 5317  Menu and Toolbar  RESOLVED     INVALID  2019-02-11 16:36:05  1514619
# 5318              Sync  RESOLVED  WORKSFORME  2019-09-18 10:10:20  1546822
# 5319           General  RESOLVED       FIXED  2021-09-20 10:02:49  1728461
#
#                                             Description  Duplicate_Bug_Ids
# 0     the symptom was that the  broadcastchannel  me...                NaN
# 1     for websites which have their own event handle...                NaN
# 2     we are seeing these crash being reported on se...                NaN
# 3     since android may send these to the services h...                NaN
# 4     this bug is for crash report bp   ebbf        ...                NaN
# ...                                                 ...                ...
# 5315    filed by    rmaries  at  mozilla com   parse...          1682775.0
# 5316  created attachment   regedt‮gpj exe  summary  ...                NaN
# 5317  created attachment             png  the hostor...                NaN
# 5318  created attachment   syncnotificationecho png ...                NaN
# 5319  on the moto   in fenix  we spend     in  inter...                NaN
#
# [5320 rows x 13 columns]

# %%
mobile_data = mobile_data.drop(columns = ["index","Unnamed: 0"])

# %%
mobile_data = mobile_data.drop_duplicates()

# %%
mobile_data
# Out:
#        Bug ID         Type                                            Summary  \
# 0     1668376       defect  Test failure in dom/base/test/test_window_clos...
# 1     1631754       defect  PanZoomController erroneously returns INPUT_RE...
# 2     1677838       defect  NumberFormatExceptionjava.lang.Integer in pars...
# 3     1686100  enhancement  Route Service.onTrimMemory notifications throu...
# 4     1630229       defect  Crash in [@ java.lang.AssertionError: at org.m...
# ...       ...          ...                                                ...
# 5315  1683643       defect  Intermittent org.mozilla.geckoview.test.Select...
# 5316  1649160       defect  Download Feature: unicode RTLO char can fake t...
# 5317  1514619       defect  Menu options are in different order than new t...
# 5318  1546822       defect  Notifications repeating if not acted on in iOS...
# 5319  1728461       defect  GeckoView unconditionally clears the startup c...
#
#               Product         Component    Status  Resolution  \
# 0           GeckoView           General  RESOLVED       FIXED
# 1           GeckoView           General  RESOLVED       FIXED
# 2           GeckoView           General  RESOLVED       FIXED
# 3           GeckoView           General  RESOLVED       FIXED
# 4           GeckoView           General  RESOLVED       FIXED
# ...               ...               ...       ...         ...
# 5315        GeckoView           General  RESOLVED   DUPLICATE
# 5316  Firefox for iOS           General  RESOLVED       FIXED
# 5317  Firefox for iOS  Menu and Toolbar  RESOLVED     INVALID
# 5318  Firefox for iOS              Sync  RESOLVED  WORKSFORME
# 5319        GeckoView           General  RESOLVED       FIXED
#
#                   Updated   Bug Id  \
# 0     2020-10-14 03:01:38  1668376
# 1     2020-05-23 04:47:46  1631754
# 2     2021-01-06 13:28:48  1677838
# 3     2021-01-12 02:17:23  1686100
# 4     2020-05-28 05:17:09  1630229
# ...                   ...      ...
# 5315  2021-07-30 19:04:17  1683643
# 5316  2020-12-18 17:20:48  1649160
# 5317  2019-02-11 16:36:05  1514619
# 5318  2019-09-18 10:10:20  1546822
# 5319  2021-09-20 10:02:49  1728461
#
#                                             Description  Duplicate_Bug_Ids
# 0     the symptom was that the  broadcastchannel  me...                NaN
# 1     for websites which have their own event handle...                NaN
# 2     we are seeing these crash being reported on se...                NaN
# 3     since android may send these to the services h...                NaN
# 4     this bug is for crash report bp   ebbf        ...                NaN
# ...                                                 ...                ...
# 5315    filed by    rmaries  at  mozilla com   parse...          1682775.0
# 5316  created attachment   regedt‮gpj exe  summary  ...                NaN
# 5317  created attachment             png  the hostor...                NaN
# 5318  created attachment   syncnotificationecho png ...                NaN
# 5319  on the moto   in fenix  we spend     in  inter...                NaN
#
# [5320 rows x 11 columns]

# %%
mobile_data = mobile_data.dropna(axis=0, subset=['Bug ID'])

# %%
mobile_data.info()

# %% [markdown]
# ## On complete JDT data

# %%
mobile_data["Description"]= mobile_data["Description"].str.replace("fixed in HEAD", "", case = False)
mobile_data["Description"]= mobile_data["Description"].str.replace("has been marked as readonly", " ", case = False)

# %%
pd.options.display.max_colwidth = 50

# %%
#Text Cleaning round 1 (removing punctutions)


def clean_text_round1(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
#     print(text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('\w*\f\w*', '', text)
    text = re.sub('\(.*?\)', '', text)
    text = re.sub('\[.*]\)', '', text)
    text = text.lower()
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    return text

round1 = lambda x: clean_text_round1(x)

# %%
mobile_data.info()

# %%
mobile_data = mobile_data.dropna(axis=0, subset=['Description'])

# %%
mobile_data['Description'] = mobile_data['Description'].apply(clean_text_round1)

# %%
# Apply a second round of cleaning (removing punctuations)
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\t', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
mobile_data['Description'] = mobile_data['Description'].apply(clean_text_round2)

# %%
def lemmatize(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 5:
            result.append(lemmatize(token))
    return result

# %%
mobile_data['Description'] = mobile_data['Description'].map(preprocess)

# %%
mobile_data['Duplicate_Bug_Ids'].isnull().sum()
# Out:
# 4758

# %%
#Saving all the duplicate reports into a csv file as a testing set
duplicate_reports = mobile_data.dropna(axis=0, subset=['Duplicate_Bug_Ids'])
duplicate_reports.reset_index(drop=True)
duplicate_reports.to_csv('mobile_duplicate_reports.csv')

# %%
#Seperating all the master reports into a dataframe
master_reports = mobile_data[mobile_data.isnull().any(axis=1)]
master_reports.reset_index(drop=True)
# Out:
#        Bug ID         Type                                            Summary  \
# 0     1668376       defect  Test failure in dom/base/test/test_window_clos...
# 1     1631754       defect  PanZoomController erroneously returns INPUT_RE...
# 2     1677838       defect  NumberFormatExceptionjava.lang.Integer in pars...
# 3     1686100  enhancement  Route Service.onTrimMemory notifications throu...
# 4     1630229       defect  Crash in [@ java.lang.AssertionError: at org.m...
# ...       ...          ...                                                ...
# 4753  1682745       defect  Intermittent org.mozilla.geckoview.test.[Gecko...
# 4754  1649160       defect  Download Feature: unicode RTLO char can fake t...
# 4755  1514619       defect  Menu options are in different order than new t...
# 4756  1546822       defect  Notifications repeating if not acted on in iOS...
# 4757  1728461       defect  GeckoView unconditionally clears the startup c...
#
#               Product         Component    Status  Resolution  \
# 0           GeckoView           General  RESOLVED       FIXED
# 1           GeckoView           General  RESOLVED       FIXED
# 2           GeckoView           General  RESOLVED       FIXED
# 3           GeckoView           General  RESOLVED       FIXED
# 4           GeckoView           General  RESOLVED       FIXED
# ...               ...               ...       ...         ...
# 4753        GeckoView           General  RESOLVED       FIXED
# 4754  Firefox for iOS           General  RESOLVED       FIXED
# 4755  Firefox for iOS  Menu and Toolbar  RESOLVED     INVALID
# 4756  Firefox for iOS              Sync  RESOLVED  WORKSFORME
# 4757        GeckoView           General  RESOLVED       FIXED
#
#                   Updated   Bug Id  \
# 0     2020-10-14 03:01:38  1668376
# 1     2020-05-23 04:47:46  1631754
# 2     2021-01-06 13:28:48  1677838
# 3     2021-01-12 02:17:23  1686100
# 4     2020-05-28 05:17:09  1630229
# ...                   ...      ...
# 4753  2020-12-20 22:19:42  1682745
# 4754  2020-12-18 17:20:48  1649160
# 4755  2019-02-11 16:36:05  1514619
# 4756  2019-09-18 10:10:20  1546822
# 4757  2021-09-20 10:02:49  1728461
#
#                                             Description  Duplicate_Bug_Ids
# 0     the symptom was that the  broadcastchannel  me...                NaN
# 1     for websites which have their own event handle...                NaN
# 2     we are seeing these crash being reported on se...                NaN
# 3     since android may send these to the services h...                NaN
# 4     this bug is for crash report bp   ebbf        ...                NaN
# ...                                                 ...                ...
# 4753    filed by    apavel  at  mozilla com   parsed...                NaN
# 4754  created attachment   regedt‮gpj exe  summary  ...                NaN
# 4755  created attachment             png  the hostor...                NaN
# 4756  created attachment   syncnotificationecho png ...                NaN
# 4757  on the moto   in fenix  we spend     in  inter...                NaN
#
# [4758 rows x 11 columns]

# %%
master_reports.Description.isna().sum()
# Out:
# 0

# %%
#Removing empty master_reports after data cleaning process
mr = pd.DataFrame()
count = 0
for i in range(len(master_reports)):
    if(len(master_reports.Description.iloc[i])>2):
        mr= mr.append(master_reports.iloc[[i]])
        count=+1

# %%
master_reports.to_csv('mobile_master_reports.csv')

# %%
#importing the CSV file of the master reports from google drive into a dataframe
master_reports = pd.read_csv('mobile_master_reports.csv')
master_reports = master_reports.drop(columns=['Unnamed: 0'])

# %%
master_reports['Description'] = master_reports['Description'].map(preprocess)

# %%
#Creating a dictionary using gensim library
dictionary = gensim.corpora.Dictionary(master_reports['Description'])
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
#Print top 20 words from the dictionary
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 20:
        break
# Out:
# 0 active
# 1 actually
# 2 assume
# 3 comment
# 4 content
# 5 correct
# 6 failure
# 7 implementation
# 8 longer
# 9 message
# 10 parent
# 11 process
# 12 purpose
# 13 understand
# 14 update
# 15 android
# 16 appear
# 17 browser
# 18 components
# 19 engine
# 20 events

# %%
#Creating BoW using the the dictionary
bow_corpus = [dictionary.doc2bow(doc) for doc in master_reports['Description']]

# %%
#Printing the BoW for single document
bow_doc_8 = bow_corpus[8]
for i in range(len(bow_doc_8)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_8[i][0], 
                                               dictionary[bow_doc_8[i][0]], 
bow_doc_8[i][1]))

# %%
# open a file, where you stored the pickled data
f= open('mobile_bow_corpus.pickle', 'wb')

# dump information to that file
pickle.dump(bow_corpus, f)

# %%
#open a file, where you stored the pickled data
file = open('mobile_dictionary.pickle', 'wb')

# dump information to that file
pickle.dump(dictionary, file)

# %%
#Preparing the parameters for LDA model
corpus = bow_corpus
no_of_topics = 10
dictionary = dictionary
p = 20
k = 2
epochs = 100

#Training the LDA model on the BoW corpus
lda_model = gensim.models.LdaMulticore(corpus, num_topics=no_of_topics, id2word=dictionary, passes=p, workers=k, iterations=epochs)

# %%
# save model to disk (no need to use pickle module)
lda_model.save('mobile_lda_model.model')

# %%
# Printing the topics and the propability distributions of words in those topics
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))

# %%
#Let's evaluate the model using Perplexity and Coherence Bag of words- Title

# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(bow_corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=mobile_data['Description'], dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -4.290205604770914
#
# Coherence Score:  0.6101025308835141

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, bow_corpus, dictionary)
vis
# Out:
# /local/pkg/python/root-python-3.7/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /users/grad/sjahan/.local/lib/python3.7/site-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2     -0.362855 -0.111536       1        1  43.979071
# 7      0.152415 -0.197933       2        1  12.843191
# 0     -0.273050 -0.054298       3        1   7.229173
# 8     -0.139062  0.056552       4        1   7.134206
# 1     -0.220245  0.095906       5        1   6.354585
# 9      0.217074 -0.145349       6        1   5.381806
# 6      0.134658  0.164156       7        1   5.065538
# 5      0.213344  0.006866       8        1   4.792498
# 4      0.195503 -0.030216       9        1   3.781989
# 3      0.082217  0.215853      10        1   3.437944, topic_info=          Term          Freq         Total Category  logprob  loglift
# 37   geckoview  18084.000000  18084.000000  Default  30.0000  30.0000
# 27     mozilla  19250.000000  19250.000000  Default  29.0000  29.0000
# 15     android   4687.000000   4687.000000  Default  28.0000  28.0000
# 30      result   1729.000000   1729.000000  Default  27.0000  27.0000
# 199    firefox   1971.000000   1971.000000  Default  26.0000  26.0000
# ..         ...           ...           ...      ...      ...      ...
# 311  currently     44.603305    304.389229  Topic10  -4.6846   1.4498
# 202    problem     38.105743    144.993701  Topic10  -4.8420   2.0340
# 66     display     44.539575    445.014132  Topic10  -4.6860   1.0686
# 73      screen     42.339074    509.842976  Topic10  -4.7367   0.8819
# 198     create     41.743236    877.406261  Topic10  -4.7508   0.3249
#
# [550 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 539      10  0.967086     ability
# 505       1  0.059121      accept
# 505       5  0.118241      accept
# 505       7  0.812909      accept
# 76        1  0.148665      access
# ...     ...       ...         ...
# 411       7  0.011303   workspace
# 708       6  0.950028    xcuitest
# 629       6  0.635199   xcuitests
# 629       8  0.362971   xcuitests
# 55        1  0.998337  zygoteinit
#
# [1219 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 8, 1, 9, 2, 10, 7, 6, 5, 4])

# %%
#Creating 10 empty clusters and pushing master reports in each of them based on topic modeling and saving them in individual csv file
for c in range(10):
    exec('topic_{} = pd.DataFrame()'.format(c))
    for i in range(len(master_reports)):
        topic=lda_model[dictionary.doc2bow(master_reports.Description[i])]
        topic= np.asarray(topic)
        if int(topic[np.argmax(topic[:,1]),0])== c:
            exec('topic_{} = topic_{}.append(master_reports.loc[[i]])'.format(c,c))
            exec('topic_{} = topic_{}.reset_index(drop=True)'.format(c,c))
            exec('topic_{}.to_csv("topic_{}.csv")'.format(c,c))

# %%
# open a file, where you stored the pickled data
f = open('mobile_bow_corpus.pickle', 'rb')
bow_corpus=pickle.load(f)

file = open('mobile_dictionary.pickle', 'rb')
dictionary=pickle.load(file)

# later on, load trained model from file
lda_model =  models.LdaModel.load('mobile_lda_model.model')

# %%
#Import all the clusters from the drive 
for c in range(10):
    exec('topic_{} = pd.read_csv("topic_{}.csv")'.format(c,c))
    exec("topic_{}= topic_{}.drop(columns=['Unnamed: 0'])".format(c,c))
    exec("topic_{}['Description'] = topic_{}['Description'].map(preprocess)".format(c,c))

# %%
for sent in range(10):
    exec('print(len(sent_{}))'.format(sent))

# %%
#Training GloVe model for each cluster
for cluster in range(10):
    vector_size = 100
    exec('glove_corpus{}=Corpus()'.format(cluster, cluster)) 
    exec('glove_corpus{}.fit(sent_{})'.format(cluster, cluster))
    exec('glove{}= Glove(no_components=vector_size, learning_rate=0.18, alpha=0.75, max_count=100, max_loss=10.0, random_state=None)'.format(cluster, cluster))
    exec('glove{}.fit(glove_corpus{}.matrix, epochs=200, no_threads=3, verbose=True)'.format(cluster, cluster))
    exec('transformer = lambda dictionary2:glove{}.transform_paragraph(words, epochs=1000,ignore_missing=False)'.format(cluster, cluster))
    exec('glove{}.add_dictionary(glove_corpus{}.dictionary)'.format(cluster, cluster))

    #Save the all the models in individual file
    exec('path = get_tmpfile("glove{}.model")'.format(cluster))
    exec('glove{}.save("glove{}.model")'.format(cluster, cluster))

# %% [markdown]
# ## Classification

# %%
# importing all the clusters created using LDA based topic modeling
for c in range(10):
    exec('topic_{} = pd.read_csv("topic_{}.csv")'.format(c,c))
    exec("topic_{}= topic_{}.drop(columns=['Unnamed: 0'])".format(c,c))
    exec("topic_{}['Description'] = topic_{}['Description'].map(preprocess)".format(c,c))

# %%
#import the duplicate reports for testing purpose
test = pd.read_csv('mobile_duplicate_reports.csv')
test = test.drop(columns=['Unnamed: 0'])

# %%
def lemmatize2(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')

def preprocess2(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 5:
            result.append(lemmatize2(token))
    return result

#import the duplicate reports for testing purpose
test_sim = pd.read_csv('mobile_textually_similar_duplicates.csv')
test_sim = test_sim.drop(columns=['Unnamed: 0'])

#import the duplicate reports for testing purpose
test_dissim = pd.read_csv('mobile_textually_dissimilar_duplicates.csv')
test_dissim = test_dissim.drop(columns=['Unnamed: 0'])

test_sim['Description']= test_sim['Description'].fillna('').astype(str).map(preprocess2)
test_dissim['Description']= test_dissim['Description'].fillna('').astype(str).map(preprocess2)

# %%
def lemmatize2(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')

def preprocess2(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 5:
            result.append(lemmatize(token))
    return result

# %%
test['Description']= test['Description'].fillna('').astype(str).map(preprocess2)

# %%
for mod in range(10):  
    #import all the trained GloVe models
    exec('glove{} = Glove.load("glove{}.model")'.format(mod, mod))

# %%
#This will return the index of cluster in which the master report of duplicate report may reside
def sim_with_clusters_lda_topn(DR, n):
    vec_bow = dictionary.doc2bow(DR)
    x= lda_model[vec_bow]
    topic = np.asarray(x)
    # max_sim = int(topic[np.argmax(topic[:,1]),0]) 
    # max_sim
    sim=[]
    x= topic[np.argsort(topic[:,1])[-n:][::-1],0]
    for i in range(len(x)):
        sim.append(int(x[i]))
    # return max_sim
    return sim

# %%
# Convert multiple word embeddings into a single document vector by averaging the word embeddings by GloVe model

def average_word_vectors_glove(words, model, vocabulary, num_features):  
    feature_vector = np.zeros((num_features,),dtype="float64")
    nwords = 0.  

    for word in words:
        if word in vocabulary: 
            nwords = nwords + 1.
            feature_vector = np.add(feature_vector, model.wv[model.wv.key_to_index[word]])

    if nwords:
        feature_vector = np.divide(feature_vector, nwords)
        
    return feature_vector
    


def averaged_word_vectorizer_glove(corpus, model, num_features):
    vocabulary = set(model.wv.key_to_index)
    if(any(isinstance(i, list) for i in corpus)):
        features = [average_word_vectors_glove(tokenized_sentence, model, vocabulary, num_features)
                      for tokenized_sentence in corpus]
        return np.array(features)
    else:
          features = average_word_vectors_glove(corpus, model, vocabulary, num_features)
    return np.array(features)

# %%
# Similarity between two feature vectors using the average of cosine similarity and euclidean similarity
def sim(vec1, vec2): 
    sim1 = 1/(1+distance.euclidean(vec1, vec2))
    sim2 = cosine_similarity(vec1, vec2)
    sim=(sim1+sim2)/2 
    return sim

# %%
# Different kinds of fusion of two master report feature vectors and two duplicate report feature vectors
def fusion(vec1, vec2, vec3, vec4, fusion_no):

    # fusion_no = 1 : concatenation of the vectors
    if (fusion_no == '1'):
        master = np.concatenate((vec1, vec2), axis=1)
        vec_duplicate = np.concatenate((vec3, vec4), axis=0)
        vec_duplicate=[vec_duplicate]
        return vec_duplicate, master

    #fusion_no = 2 : average of the vectors
    elif (fusion_no == '2'):
        vec3 = [vec3]
        vec4 = [vec4]
        avg1 = (np.add(vec1, vec2))/2
        avg2 = (np.add(vec3, vec4))/2
        return avg2, avg1

    #fusion_no = 3 : Dimensionality reduction using PCA on concatenation of the vectors
    elif (fusion_no == '3'):
        master = np.concatenate((vec1, vec2), axis=1)
        pca = PCA(n_components=100)
        avg_fit = pca.fit(master)
        master = pca.transform(master)
        vec_duplicate = np.concatenate((vec3, vec4), axis=0)
        vec_duplicate=[vec_duplicate]
        vec_duplicate = pca.transform(vec_duplicate)
        return vec_duplicate, master

    #fusion_no = 3 : Dimensionality reduction using PCA on average of the vectors
    elif (fusion_no == '4'):
        vec3 = [vec3]
        vec4 = [vec4]
        avg1 = (np.add(vec1, vec2))/2
        pca = PCA(n_components=100)
        avg_fit = pca.fit(avg1)
        master = pca.transform(avg1)
        avg2 = (np.add(vec3, vec4))/2
        vec_duplicate = pca.transform(avg2)
        return vec_duplicate, master

    else:
        raise ValueError('Invalid value for fusion')

# %%
# creation of feature vectors by multimodality feature extraction
def feature_vectors_multi_modality(DR, corpus, model1, model2, fusion_no):
    master_glove2 = averaged_word_vectorizer_glove(corpus=sent, model=model2, num_features=100)
    vec_duplicate2 = averaged_word_vectorizer_glove(corpus=DR, model=model2, num_features=100)
    vec_duplicate , master= fusion(master_glove2,vec_duplicate2, fusion_no)
    return vec_duplicate,master

# %%
# creation of feature vectors by singlemodality feature extraction
def feature_vectors_single_modality(DR, corpus, model1):
    master = averaged_word_vectorizer_glove(corpus=sent, model=model1, num_features=100)

    vec_duplicate = averaged_word_vectorizer_glove(corpus=DR, model=model1, num_features=100)

    vec_duplicate = [vec_duplicate]

    return vec_duplicate, master

# %%
# Recall Rate for Top-2.5K reports (Because Top-N where N = n * topn (2.5K = 3*833)) 
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(10)

# %%
test
# Out:
#       Bug ID    Type                                            Summary  \
# 0    1655196  defect             High ratio of ERROR_NO_MINIDUMP_HEADER
# 1    1672552  defect  BrowserParent::GetDocShellIsActive returns fal...
# 2    1672566  defect                 [Bug] TransactionTooLargeException
# 3    1482876  defect  Storage crash: lastInsertedRowID, 32-bit only,...
# 4    1375994  defect      Unclear how the app icon badge is incremented
# ..       ...     ...                                                ...
# 557  1521741  defect  In Reader mode, specific article on English Wi...
# 558  1683402  defect  Intermittent org.mozilla.geckoview.test.PanZoo...
# 559  1683466  defect  Intermittent org.mozilla.geckoview.test.Select...
# 560  1683596  defect  Intermittent org.mozilla.geckoview.test.Progre...
# 561  1683643  defect  Intermittent org.mozilla.geckoview.test.Select...
#
#              Product         Component    Status Resolution  \
# 0          GeckoView           General  RESOLVED  DUPLICATE
# 1          GeckoView           General  RESOLVED  DUPLICATE
# 2          GeckoView           General  RESOLVED  DUPLICATE
# 3    Firefox for iOS           General  RESOLVED  DUPLICATE
# 4    Firefox for iOS  Firefox Accounts  RESOLVED  DUPLICATE
# ..               ...               ...       ...        ...
# 557  Firefox for iOS       Reader View  RESOLVED  DUPLICATE
# 558        GeckoView           General  RESOLVED  DUPLICATE
# 559        GeckoView           General  RESOLVED  DUPLICATE
# 560        GeckoView           General  RESOLVED  DUPLICATE
# 561        GeckoView           General  RESOLVED  DUPLICATE
#
#                  Updated   Bug Id  \
# 0    2021-02-04 09:57:49  1655196
# 1    2020-10-28 07:48:06  1672552
# 2    2020-11-12 22:21:38  1672566
# 3    2018-08-14 08:14:18  1482876
# 4    2017-06-28 10:58:10  1375994
# ..                   ...      ...
# 557  2019-09-30 06:44:59  1521741
# 558  2021-07-30 19:04:11  1683402
# 559  2021-07-30 19:04:12  1683466
# 560  2021-07-30 19:04:15  1683596
# 561  2021-07-30 19:04:17  1683643
#
#                                            Description  Duplicate_Bug_Ids
# 0    [gsvelto, android, minidump, header, fundament...          1644486.0
# 1    [provide, simple, confirm, couldn, figure, con...          1673316.0
# 2    [github, mobile, reproduce, change, password, ...          1672095.0
# 3    [report, thread, thread, storage, storage, sto...          1482487.0
# 4    [unclear, incremented, example, screen, curren...          1374987.0
# ..                                                 ...                ...
# 557  [animals, austronesia, reader, rightmost, port...           782423.0
# 558  [rmaries, mozilla, autoland, service, mozilla,...          1643815.0
# 559  [ncsoregi, mozilla, autoland, service, mozilla...          1682775.0
# 560  [nbeleuzu, mozilla, autoland, service, mozilla...          1682775.0
# 561  [rmaries, mozilla, autoland, service, mozilla,...          1682775.0
#
# [562 rows x 11 columns]

# %%
test = test.rename(columns={'Bug ID':'Bug_ID'})

# %%
def compare_topn(model1, cluster, sent, DR, topn, modal):
    similarity=[]
    if (modal == 'single'):
        vec_duplicate, master= feature_vectors_single_modality(DR, sent, model1)

    else:
        raise ValueError('Invalid Modality entered')

    for doc in range(len(master)):
        vec_master = master[doc]
        vec_master= [vec_master]
        unified_sim = sim(vec_duplicate, vec_master)

        similarity.append(unified_sim)
    similarity = np.asarray(similarity)
    similarity= np.concatenate(similarity, axis=0 )
    similarity= np.concatenate(similarity, axis=0 )
    max_similar_reports=similarity.argsort()[-topn:][::-1][1:]
    
    # # # for d,f in enumerate(max_similar_reports):
    # # #     similar_reports= similar_reports.append(cluster.loc[[f]])
    return(max_similar_reports)

# %% [markdown]
# # LDA and GLOVE

# %%
#Returns Top-N master reports
dup_id = test.Duplicate_Bug_Ids
def compare_topn2(model1, cluster, sent, DR, topn, modal):
    similarity=[]
    if (modal == 'single'):
        vec_duplicate, master= feature_vectors_single_modality2(DR, sent, model1)

    else:
        raise ValueError('Invalid Modality entered')

    for doc in range(len(master)):
        vec_master = master[doc]
        vec_master= [vec_master]
        unified_sim = sim(vec_duplicate, vec_master)

        similarity.append(unified_sim)
    similarity = np.asarray(similarity)
    similarity= np.concatenate(similarity, axis=0 )
    similarity= np.concatenate(similarity, axis=0 )
    max_similar_reports=similarity.argsort()[-topn:][::-1]
    return(max_similar_reports)

# %%
# creation of feature vectors by singlemodality feature extraction
def feature_vectors_single_modality2(DR, corpus, model1):
    master = averaged_word_vectorizer_glove2(corpus=sent, model=model1, num_features=100)

    vec_duplicate = averaged_word_vectorizer_glove2(corpus=DR, model=model1, num_features=100)

    vec_duplicate = [vec_duplicate]

    return vec_duplicate, master

# %%
def average_word_vectors_glove2(words, model, vocabulary, num_features):  
    feature_vector = np.zeros((num_features,),dtype="float64")
    nwords = 0.  

    for word in words:
        if word in vocabulary: 
            nwords = nwords + 1.
            feature_vector = np.add(feature_vector, model.word_vectors[model.dictionary[word]])

    if nwords:
        feature_vector = np.divide(feature_vector, nwords)
        
    return feature_vector
def averaged_word_vectorizer_glove2(corpus, model, num_features):
    vocabulary = set(model.dictionary)
    if(any(isinstance(i, list) for i in corpus)):
        features = [average_word_vectors_glove2(tokenized_sentence, model, vocabulary, num_features)
                      for tokenized_sentence in corpus]
        return np.array(features)
    else:
          features = average_word_vectors_glove2(corpus, model, vocabulary, num_features)
    return np.array(features)

# %% [markdown]
# # Test data

# %% [markdown]
# Determining the top-n values for the recall rate @ k

# %%
import math

print(math.floor(1/3))
print(math.floor(5/3))
print(math.floor(10/3))
print(math.floor(20/3))
print(math.floor(25/3))
print(math.floor(30/3))
print(math.floor(50/3))
print(math.floor(75/3))
print(math.floor(100/3))

# %%
#top1
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 1
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 1                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
        
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top5
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 1                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
        
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top10
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 3                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
        
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top20
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 6                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
        
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top25
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 8                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
        
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top30
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 10                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
        
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top50
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 16                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top75
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 25                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
        
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top100
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})
        topn = 33                                         #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
        
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %% [markdown]
# # On Textually Similar and Dissimilar

# %% [markdown]
# #### Textually Similar & Dissimilar Datasets

# %%
def lemmatize2(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')


def preprocess2(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 5:
            result.append(lemmatize2(token))
    return result

#import the duplicate reports for testing purpose
test_sim = pd.read_csv('mobile_textually_similar_duplicates.csv')
# test_sim = test_sim.drop(columns=['Unnamed: 0'])

#import the duplicate reports for testing purpose
test_dissim = pd.read_csv('mobile_textually_dissimilar_duplicates.csv')
# test_dissim = test_dissim.drop(columns=['Unnamed: 0'])

test_sim['Description']= test_sim['Description'].fillna('').astype(str).map(preprocess2)
test_dissim['Description']= test_dissim['Description'].fillna('').astype(str).map(preprocess2)

def lemmatize2(text):
    return WordNetLemmatizer().lemmatize(text, pos='v')

def preprocess2(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 5:
            result.append(lemmatize2(token))
    return result

test_dissim['Description']= test_dissim['Description'].fillna('').astype(str).map(preprocess2)
test_sim['Description']= test_sim['Description'].fillna('').astype(str).map(preprocess2)

nan_value = float("NaN")
test_sim.replace("", nan_value, inplace=True)
test_sim.dropna(subset = ["Duplicate_Bug_Ids"], inplace=True)

nan_value = float("NaN")
test_dissim.replace("", nan_value, inplace=True)
test_dissim.dropna(subset = ["Duplicate_Bug_Ids"], inplace=True)

cond = (test_sim['Duplicate_Bug_Ids'] == 'NaN')
cond.unique()

cond = (test_dissim['Duplicate_Bug_Ids'] == 'NaN')
cond.unique()

test_sim = test_sim.reset_index(drop=True)
test_dissim = test_dissim.reset_index(drop=True)

# %% [markdown]
# ## Textually Similar evaluation

# %%
#top 1
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 1
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 1                                         #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 5
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 1                                         #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 10
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 3                                         #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 20
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 6                                         #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 25
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 8                                         #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 30
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 10                                         #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 50
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 16                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 75
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 25                                         #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 100
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_sim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 33                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_sim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %% [markdown]
# ## Textually Dissimilar Evaluation

# %%
#top 1
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 1
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 1                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 5
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 1                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 10
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 3                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 20
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 6                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 25
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 8                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 30
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 10                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 50
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 16                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 75
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 25                                          #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")

# %%
#top 100
vec_acc=[]
t1 = time.time()
no_of_test_samples= int(200)
for i in range(no_of_test_samples):
    print(f'\rRunning sample {i}', end='')
    sample = test_dissim.Description[i] #The test sample (duplicate report)
    n = 3
    max_cluster =sim_with_clusters_lda_topn(sample, n)
    v=[]
#     print(i)
    for max in max_cluster:
        exec('cluster = topic_{}'.format(max))              #The predicted cluster
#         exec('model1 = ftmodel{}'.format(max))              #The trained FastText model for the predicted cluster   (can be changed to other model as well viz. glove or word2vec)
        exec('model1 = glove{}'.format(max))                #The trained Word2Vec model for the predicted cluster   (Doesn't count if using single modality)
        exec('sent = topic_{}.Description'.format(max))     #The vocabulary for the predicted cluster
        cluster = cluster.rename(columns={'Bug ID':'Bug_ID'})

        topn = 33                                         #The number of predicted master report for single predicted cluster
        fusion_no = '4'   #Doesn't count if single modality #The selection of fusion used to fuse the word embeddings of two different models  (4 gives the best results)
        modal = 'single'                                    #Whether you want to use single feature extraction model or multi model ( for single, it'll consider just model1)
         #This will return the Top-N predicted master reports
        max_sim = compare_topn2(model1,cluster, sent, sample, topn, modal)
        t2 = time.time()

        #Comparing the predicted value to the ground truth
        for num in max_sim:
            if (cluster.Bug_ID[num] == test_dissim.Duplicate_Bug_Ids[i]):
                v.append("1")
            else:
                v.append("0")

    if(all(x==v[0] for x in v)):
        vec_acc.append("0")
    else:
        vec_acc.append("1")
#Evaluating the performance by Recall Rate
sum = 0
for i,num in enumerate(vec_acc):
    sum = sum + int(num)
recall_rate = (sum/len(vec_acc))*100
print("Recall Rate : {} %".format(recall_rate))
print("Time : ", (t2-t1)/60, "min")
